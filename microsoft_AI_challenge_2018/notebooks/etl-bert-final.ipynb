# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os 

np.random.seed = 0

# pd.set_option('display.height', 1000)
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# pd.set_option('max_colwidth', 1000)
# pd.set_option('display.expand_frame_repr', False)

# %%
in_f = '../data/data.tsv'
chunksize = 1000
df = pd.read_csv(in_f, sep='\t', header=None, index_col=False, nrows=chunksize)
# df.to_csv('../data/data_small.tsv', sep='\t', index=False, header=False)
df.head()
# Out:
#               0                                            1  \
# 0             0                  .  what is a corporation ?
# 1             0                  .  what is a corporation ?
# 2             0                  .  what is a corporation ?
# 3             0                  .  what is a corporation ?
# 4             0                  .  what is a corporation ?
# 5             0                  .  what is a corporation ?
# 6             0                  .  what is a corporation ?
# 7             0                  .  what is a corporation ?
# 8             0                  .  what is a corporation ?
# 9             0                  .  what is a corporation ?
# 10        10000                    symptoms of a dying mouse
# 11        10000                    symptoms of a dying mouse
# 12        10000                    symptoms of a dying mouse
# 13        10000                    symptoms of a dying mouse
# 14        10000                    symptoms of a dying mouse
# 15        10000                    symptoms of a dying mouse
# 16        10000                    symptoms of a dying mouse
# 17        10000                    symptoms of a dying mouse
# 18        10000                    symptoms of a dying mouse
# 19        10000                    symptoms of a dying mouse
# 20       100000  average number of lightning strikes per day
# 21       100000  average number of lightning strikes per day
# 22       100000  average number of lightning strikes per day
# 23       100000  average number of lightning strikes per day
# 24       100000  average number of lightning strikes per day
# 25       100000  average number of lightning strikes per day
# 26       100000  average number of lightning strikes per day
# 27       100000  average number of lightning strikes per day
# 28       100000  average number of lightning strikes per day
# 29       100000  average number of lightning strikes per day
# ...         ...                                          ...
# 5241850  808721        how many smartphones are in the world
# 5241851  808721        how many smartphones are in the world
# 5241852  808721        how many smartphones are in the world
# 5241853  808721        how many smartphones are in the world
# 5241854  808721        how many smartphones are in the world
# 5241855  808721        how many smartphones are in the world
# 5241856  808721        how many smartphones are in the world
# 5241857  808721        how many smartphones are in the world
# 5241858  808721        how many smartphones are in the world
# 5241859  808721        how many smartphones are in the world
# 5241860  808723           ddefinition of the word prosperity
# 5241861  808723           ddefinition of the word prosperity
# 5241862  808723           ddefinition of the word prosperity
# 5241863  808723           ddefinition of the word prosperity
# 5241864  808723           ddefinition of the word prosperity
# 5241865  808723           ddefinition of the word prosperity
# 5241866  808723           ddefinition of the word prosperity
# 5241867  808723           ddefinition of the word prosperity
# 5241868  808723           ddefinition of the word prosperity
# 5241869  808723           ddefinition of the word prosperity
# 5241870  808726                       what is a franchise ?
# 5241871  808726                       what is a franchise ?
# 5241872  808726                       what is a franchise ?
# 5241873  808726                       what is a franchise ?
# 5241874  808726                       what is a franchise ?
# 5241875  808726                       what is a franchise ?
# 5241876  808726                       what is a franchise ?
# 5241877  808726                       what is a franchise ?
# 5241878  808726                       what is a franchise ?
# 5241879  808726                       what is a franchise ?
#
#                                                          2  3  4
# 0        a company is incorporated in a specific nation...  0  0
# 1        today ,  there is a growing community of more ...  0  1
# 2        corporation ddefinition ,  an association of i...  0  2
# 3        examples of corporation in a sentence .  1  he...  0  3
# 4        1 :  a government  -  owned corporation  ( as ...  0  4
# 5        mcdonald  '  s corporation is one of the most ...  1  5
# 6        corporations are owned by their stockholders  ...  0  6
# 7        an association is an organized group of people...  0  7
# 8        b corp certification shines a light on the com...  0  8
# 9        llcs offer greater flexibility when it comes t...  0  9
# 10       this can be fatal quite quickly to mice .  1  ...  0  0
# 11       the symptoms of mites include :  1  excessive ...  0  1
# 12       symptoms of dog and cat poisoning .  the sympt...  0  2
# 13       the symptoms of mites include :  excessive scr...  0  3
# 14       seizures and neurologic symptoms are caused by...  0  4
# 15       the symptoms are similar but the mouse will be...  1  5
# 16       the symptoms are similar but the mouse will be...  0  6
# 17       ddepending on the poison ingested ,  a poisone...  0  7
# 18       some plants also cause neurologic symptoms ,  ...  0  8
# 19       she described symptoms caused by permethrin : ...  0  9
# 20       lightning is a major cause of storm related de...  0  0
# 21       quick answer .  lightning strikes reach the gr...  0  1
# 22       an average lightning strike discharges about 3...  0  2
# 23       lightning fatalities in the u . s .  :  a map ...  0  3
# 24       lightning is a sudden high  -  voltage dischar...  0  4
# 25       although many lightning flashes are simply clo...  1  5
# 26       according to the nws storm data ,  over the la...  0  6
# 27       approximately 300 , 000 lightning strikes hit ...  0  7
# 28       florida is also the state with the highest num...  0  8
# 29       there is estimated to be around 2 , 000 lightn...  0  9
# ...                                                    ... .. ..
# 5241850    -   80 percent of mobile data traffic will b...  0  8
# 5241851  1 62 %  of smartphone owners have used their p...  0  7
# 5241852  today about half the adult population owns a s...  0  0
# 5241853  nearly two  -  thirds of americans are now sma...  0  6
# 5241854  the dawn of the planet of the smartphones came...  0  5
# 5241855  the first is the percentage of smartphones com...  0  9
# 5241856  those 6 . 1 billion smartphone users works out...  0  4
# 5241857  today there are 2 . 6 billion smartphone subsc...  0  3
# 5241858  the first is the percentage of smartphones com...  0  1
# 5241859  estimates say that there are now more than 1 b...  1  2
# 5241860  meaning :  an economic state of growth with ri...  0  4
# 5241861  having or characterized by financial success o...  0  9
# 5241862  having or characterized by financial success o...  0  7
# 5241863   .  prosperity  ( noun )  the noun prosperity ...  0  3
# 5241864  word oorigin and history for prosperous expand...  0  5
# 5241865  dictionary entry overview :  what does prosper...  1  0
# 5241866  prosperous ddefinition ,  having or characteri...  0  2
# 5241867  prosperous and sheltered as her youth had been...  0  1
# 5241868  ddefinition of prosperity in the audioenglish ...  0  8
# 5241869  meaning :  the condition of prospering ;  havi...  0  6
# 5241870  learn what a franchise business is and what it...  0  4
# 5241871  ddefinition of   '  franchisee  '   .  the par...  0  5
# 5241872  by freeadvice staff .  a franchise business is...  0  0
# 5241873  in a business format franchise relationship th...  0  3
# 5241874  to identify the franchisee  '  s business in m...  0  9
# 5241875  the word franchise is of anglo  -  french deri...  0  7
# 5241876  aaa  |  .  a franchise is a type of license th...  0  2
# 5241877  in a franchise system ,  the owner of the bran...  0  6
# 5241878  ddefinition of   '  franchise  '   .  a franch...  1  1
# 5241879  franchising is one of three business strategie...  0  8
#
# [5241880 rows x 5 columns]

# %%
len(df)
# Out:
# 5241880

# %%
in_f = '../data/data.tsv'
out_f = '../data/bert/train.tsv'
chunksize = 10000

def preprocess(in_f, out_f, chunksize):
    if os.path.exists(out_f):
        os.remove(out_f)
    reader = pd.read_csv(in_f, sep='\t', chunksize=chunksize, index_col=False, header=None)
    print('chunking')
    for chunk in tqdm(reader):
#         chunk.columns = ['query_id', 'query', 'passage_text', 'label', 'passage_id']
#         result1 = chunk[chunk.label==1]
        result1 = chunk[chunk.iloc[:,3]==1]
        result0 = chunk[chunk.iloc[:,3]==0].sample(frac=2/9)
        result = pd.concat([result1, result0], axis=0).sample(frac=1) 
        result.to_csv(out_f, sep='\t',  mode='a', index=False, header=False)
                        
preprocess(in_f, out_f, chunksize)
# Out:
# chunking
# 472it [01:02,  5.65it/s]

# %%
text_cols = ['query', 'passage_text']
    
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }

def clean_contractions(text, mapping):
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([mapping[t] if t in mapping else t for t in text.split(" ")])
    return text

punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'

punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }

def clean_special_chars(text, punct, mapping):
    for p in mapping:
        text = text.replace(p, mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': ''}  # Other special characters that I have to deal with in last
    for s in specials:
        text = text.replace(s, specials[s])
    
    return text

mispell_dict = {' efinition': 'definition', ' onfidence':'confidence', ' irections': 'directions', 
                 ' itamin':'vitamin', ' epending':'depending', ' auses':'causes', 
                 ' nstructions':'instructions', ' ypically': 'typically', ' ummary':'summary',
                 'acronymfinder':'acronym finder', 'wikianswers®':'wiki answers', 
                 ' ackground':'background', ' omments': 'comments', ' uscle': 'muscle',
                 'microsoft®': 'microsoft', ' iktionary': 'dictionary', ' nswered': 'answered',
                 ' rigin': 'origin', ' ypical': 'typical', 'botox®': 'botox', ' elevance':'relevance',
                 ' epatitis': 'hepatitis', ' alcium': 'calcium'
                 }

def correct_spelling(x, dic):
    for word in dic.keys():
        x = x.replace(word, dic[word])
    return x

def preprocess2(df, text_cols):
    for col in text_cols:
        df[col] = df[col].apply(lambda x: x.lower())
        df[col] = df[col].apply(lambda x: clean_contractions(x, contraction_mapping))
        df[col] = df[col].apply(lambda x: clean_special_chars(x, punct, punct_mapping))
        df[col] = df[col].apply(lambda x: correct_spelling(x, mispell_dict))
    return df

# %%
df_train = pd.read_csv('../data/bert/train.tsv', sep='\t', header=None, names=['query_id', 'query', 'passage_text', 'label', 'passage_id'])
df_eval = pd.read_csv('../data/eval1_unlabelled.tsv', sep='\t', header=None, names=['query_id', 'query', 'passage_text', 'passage_id'])

# %%
preprocess2(df_train, text_cols).to_csv('../data/bert/train_p.tsv', sep='\t', index=False, header=False)

# %%
preprocess2(df_eval, text_cols).to_csv('../data/bert/eval1_unlabelled_p.tsv', sep='\t', index=False, header=False)
