# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os 

np.random.seed = 0

# pd.set_option('display.height', 1000)
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# pd.set_option('max_colwidth', 1000)
# pd.set_option('display.expand_frame_repr', False)

# %%
in_f = '../data/data.tsv'
df = pd.read_csv(in_f, sep='\t', header=None, index_col=False)
df
# Out:
#          0                                                  1  \
# 0    10582                            time in dayton ohio now
# 1    10592                           bryan orthopedic surgeon
# 2   100208                        how much is a video editor?
# 3    10546                 ticket price for metallica concert
# 4   100548                     can you eat potatoes on a diet
# 5    10150                       technical catalog definition
# 6    10062                              synonym for in charge
# 7   100974                  amazon web service contact number
# 8    10232                        temperature lithopolis ohio
# 9    10088                               synonyms of ignorant
# 10  100529         how many product lines does coca cola have
# 11   10379                  the florida keys historic islands
# 12    1024                                   does a gas flow?
# 13  100700                      how many inches between studs
# 14   10398              the largest city in the us population
# 15    1069       does massachusetts pay sales tax on clothing
# 16   10263                                         tet effect
# 17    1054                                does e coli feed on
# 18   10658                     tollhouse ca is in what county
# 19   10549                              tidal zone definition
# 20   10465               the price to have acrylic nails done
# 21  100508                              does exercise help ms
# 22  100862                               can you freeze plums
# 23   10499  the vertical distance between trough and crest...
# 24  100772        how do you sort cells by last name in excel
# 25  100674           centurylink how to request faster speeds
# 26   10484              the state of matter in the mesosphere
# 27    1039                         does boeing pay a dividend
# 28  100496                          cancel ups shipping label
# 29   10280  the _______ is the site of cellular respiratio...
# ..     ...                                                ...
# 65   10381       the function of the olfactory nerve concerns
# 66   10703                     trailer hitches installed cost
# 67    1060                     does geothermal heating exist?
# 68  100460                              how many people in us
# 69  100931                        bbq pork chops on the grill
# 70    1036                       does basaltic lava flow fast
# 71  100711                        common types of skin cancer
# 72   10700                          trading what is sentiment
# 73   10465               the price to have acrylic nails done
# 74  100075                  how much fat is in a bubba burger
# 75  101058               how many casinos are there in canada
# 76  100686                                 arid bilge systems
# 77   10395                                  the jrp group llc
# 78  100175                                 definition of jape
# 79   10551                       tigers eye gemstone benefits
# 80   10435                          the meaning of tournament
# 81  101091                          average vehicle age in us
# 82   10062                              synonym for in charge
# 83   10155                 technology in marketing definition
# 84  100374                       how much does aluminum weigh
# 85  100977                        causes of insomnia in women
# 86   10677                                     toques meaning
# 87  101051                      costs involved in a refinance
# 88    1039                         does boeing pay a dividend
# 89  100126               how do i achieve my sphr certificate
# 90   10685                   total number us school shootings
# 91   10728                                    bula definition
# 92   10355  the difference between de facto and de jure di...
# 93   10342                  the definition of critical period
# 94  100480                average tuition aid rice university
#
#                                                     2  3  4
# 0   Current Local Time: Dayton, Ohio is in the Eas...  1  0
# 1   Dr. Bryan Ming is an orthopedic surgeon in For...  1  0
# 2   500-800 a day freelance, mostly reality, in LA...  0  5
# 3   No matter what you're looking to spend, Vivid ...  1  6
# 4   Potato has about 100 calories in it, so if you...  0  4
# 5   Defining IT Service Parameters. 1  People – th...  0  0
# 6   charge - the quantity of unbalanced electricit...  0  7
# 7   Amazon’s Customer Service line: 1  1-866-216-1...  1  1
# 8   Lithopolis weather forecast from AccuWeather.c...  0  3
# 9   ignorant 1 benighted, blind to, inexperienced,...  1  9
# 10  Watching companies compete is fascinating; it ...  0  9
# 11  The Florida Keys are an island archipelago ext...  1  3
# 12  How Does the Natural Gas Delivery System Work?...  1  4
# 13  Accurately measure the distance between the ve...  0  2
# 14  What follows is a listing of the 20 largest ci...  0  8
# 15  Massachusetts doesn't collect sales tax on pur...  1  9
# 16  Effects of the Tet Offensive. Indeed, with U.S...  0  3
# 17  Antibiotics kill E. coli bacteria that cause b...  0  3
# 18  ECONOMY. 1  The unemployment rate in Tollhouse...  0  2
# 19  Intertidal zone. The intertidal zone, also kno...  1  5
# 20  How to take care of acrylic nails. 1  Always k...  0  8
# 21  Types of exercises beneficial for someone with...  1  7
# 22  Three Methods:Dry-Freezing PlumsPacking Plums ...  1  0
# 23  Wind speed and direction, called fetch, makes ...  0  8
# 24  You can sort all the rows in a worksheet by so...  0  0
# 25  I have century link for my isp and it is suppo...  0  5
# 26  The ionosphere is located between 46 and 621 m...  0  9
# 27  Boeing is affected by increasing costs of deve...  1  0
# 28  You can void your shipping label if it has bee...  0  2
# 29  Quick Answer. The mitochondria of the eukaryot...  1  8
# ..                                                ... .. ..
# 65  Function of the Olfactory Nerve. The olfactory...  1  4
# 66  Expert Village provides a video demonstrating ...  1  4
# 67  Geothermal energy is called a renewable energy...  1  7
# 68  Aug 31, 2011 It is not difficult to find the i...  1  4
# 69  3Add to grill over direct high heat with lid c...  1  1
# 70  Other types of lavas include block lava, which...  0  6
# 71  Squamous cell carcinoma (SCC) SCC is the secon...  0  1
# 72  There are many different sentiment indicators ...  0  5
# 73  Quick Answer. The cost of having acrylic nails...  1  6
# 74  Full of BUBBA quality and flavor, these burger...  0  7
# 75  Casinos in Canada. Casino gambling in Canadian...  1  1
# 76  We purchased an Arid Bilge System Series 1 uni...  0  7
# 77  JRP Financial Group LLC is an investment advis...  1  2
# 78  You could also say that you love your annual h...  0  3
# 79  How to use tiger eye: 1  Wear tiger eye jewelr...  0  0
# 80  Translations for 'tournament'. British English...  0  1
# 81  Better quality raises average age of cars on U...  1  3
# 82  Synonyms for In charge: in charge (noun) domin...  1  5
# 83  Marketing Strategy Definition marketing strate...  1  8
# 84  Quick Answer. One cubic inch of aluminum weigh...  1  9
# 85  Although it is a sleep disorder on its own, in...  0  8
# 86  toque. 1  a brimless and close-fitting hat for...  1  4
# 87  Discharge fees. When you refinance your mortga...  0  5
# 88  Boeing's growth rates indicate it is a financi...  0  5
# 89  If you’re an experienced, senior level human r...  1  3
# 90  There are no recorded school shootings in Dela...  0  1
# 91  bula. to bubble; to lather; to cover with suds...  1  5
# 92  Difference Between De jure and De facto Meanin...  1  1
# 93  Critical period definition: a period in a life...  0  4
# 94  This is 17% LOWER than the average for Private...  0  4
#
# [95 rows x 5 columns]

# %%
len(df)
# Out:
# 95

# %%
split=0.95
rows = len(df)

rows_train = int(np.floor(rows*split))
print(rows_train)

df.iloc[:rows_train,].to_csv('../data/bert/train.tsv', sep='\t', index=False, header=False)
df.iloc[rows_train:,].to_csv('../data/bert/dev.tsv', sep='\t', index=False, header=False)
# Out:
# 90

# %%
text_cols = ['query', 'passage_text']
    
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }

def clean_contractions(text, mapping):
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([mapping[t] if t in mapping else t for t in text.split(" ")])
    return text

punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'

punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }

def clean_special_chars(text, punct, mapping):
    for p in mapping:
        text = text.replace(p, mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': ''}  # Other special characters that I have to deal with in last
    for s in specials:
        text = text.replace(s, specials[s])
    
    return text

mispell_dict = {'efinition': 'definition', 'onfidence':'confidence', 'irections': 'directions', 
                 'itamin':'vitamin', 'epending':'depending', 'auses':'causes', 
                 'nstructions':'instructions', 'ypically': 'typically', 'ummary':'summary',
                 'acronymfinder':'acronym finder', 'wikianswers®':'wiki answers', 
                 'ackground':'background', 'omments': 'comments', 'uscle': 'muscle',
                 'microsoft®': 'microsoft', 'iktionary': 'dictionary', 'nswered': 'answered',
                 'rigin': 'origin', 'ypical': 'typical', 'botox®': 'botox', 'elevance':'relevance',
                 'epatitis': 'hepatitis', 'alcium': 'calcium'
                 }

def correct_spelling(x, dic):
    for word in dic.keys():
        x = x.replace(word, dic[word])
    return x

def preprocess2(df, text_cols):
    for col in text_cols:
        df[col] = df[col].apply(lambda x: x.lower())
        df[col] = df[col].apply(lambda x: clean_contractions(x, contraction_mapping))
        df[col] = df[col].apply(lambda x: clean_special_chars(x, punct, punct_mapping))
        df[col] = df[col].apply(lambda x: correct_spelling(x, mispell_dict))
    return df

# %%
df_train = pd.read_csv('../data/bert/train.tsv', sep='\t', header=None, names=['query_id', 'query', 'passage_text', 'label', 'passage_id'])
df_validationdata = pd.read_csv('../data/bert/dev.tsv', sep='\t', header=None, names=['query_id', 'query', 'passage_text', 'label', 'passage_id'])
df_eval = pd.read_csv('../data/bert/eval1_unlabelled.tsv', sep='\t', header=None, names=['query_id', 'query', 'passage_text', 'passage_id'])

# %%
preprocess2(df_train, text_cols).to_csv('../data/bert/train_p.tsv', sep='\t', index=False, header=False)

# %%
preprocess2(df_validationdata, text_cols).to_csv('../data/bert/dev_p.tsv', sep='\t', index=False, header=False)

# %%
preprocess2(df_eval, text_cols).to_csv('../data/bert/eval1_unlabelled_p.tsv', sep='\t', index=False, header=False)
