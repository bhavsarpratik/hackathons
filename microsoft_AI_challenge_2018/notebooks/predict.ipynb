# %%
from collections import Counter
import pickle

from keras.models import load_model
from keras.preprocessing import sequence, text

import pandas as pd
import numpy as np
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('../data/eval1_unlabelled.tsv', sep='\t', names=['query_id', 'query_text', 'passage_text', 'passage_id'])
data.head()
# Out:
#    query_id                                 query_text  \
# 0   1135787  distance between erie in buffalo new york
# 1   1135787  distance between erie in buffalo new york
# 2   1135787  distance between erie in buffalo new york
# 3   1135787  distance between erie in buffalo new york
# 4   1135787  distance between erie in buffalo new york
#
#                                         passage_text  passage_id
# 0  Erie Canal Distance Tables The Erie Canal is t...           0
# 1  What is the distance between Erie AND Buffalo?...           1
# 2  The distance between Erie and Buffalo in a str...           2
# 3  Erie Canal Distances. Erie Canal Distance Tabl...           3
# 4  Erie's Metropolitan Area consists of approxima...           4

# %%
with open('../data/tokenizer.pkl', 'rb') as f:
    tk = pickle.load(f)
    
max_len_q = 12
max_len_p = 20

print('Tokenizing...')

tk.fit_on_texts(list(data.query_text.values.astype(str)) + list(data.passage_text.values.astype(str)))

x1 = tk.texts_to_sequences(data.query_text.values.astype(str))
x1 = sequence.pad_sequences(x1, maxlen=max_len_q)

x2 = tk.texts_to_sequences(data.passage_text.values.astype(str))
x2 = sequence.pad_sequences(x2, maxlen=max_len_p)
x1.shape
# Out:
# Tokenizing...
# (104170, 12)

# %%
model = load_model('../data/siamese-model1to9.h5')

# %%
data['cs'] = model.predict([x1, x2, x1, x2, x1, x2])
data.head()
# Out:
#    query_id                                 query_text  \
# 0   1135787  distance between erie in buffalo new york
# 1   1135787  distance between erie in buffalo new york
# 2   1135787  distance between erie in buffalo new york
# 3   1135787  distance between erie in buffalo new york
# 4   1135787  distance between erie in buffalo new york
#
#                                         passage_text  passage_id        cs
# 0  Erie Canal Distance Tables The Erie Canal is t...           0  0.613683
# 1  What is the distance between Erie AND Buffalo?...           1  0.524932
# 2  The distance between Erie and Buffalo in a str...           2  0.524932
# 3  Erie Canal Distances. Erie Canal Distance Tabl...           3  0.521216
# 4  Erie's Metropolitan Area consists of approxima...           4  0.506737

# %%
uniq, index = np.unique(data['query_id'], return_index=True)
query_id = uniq[index.argsort()]
query_id[:5]
# Out:
# array([1135787,  281922,  120233,  319757,  193633])

# %%
scores = data['cs'].values.reshape(-1,10)
print(scores.shape)
scores
# Out:
# (10417, 10)
# array([[0.6136826 , 0.52493227, 0.52493227, ..., 0.5608517 , 0.4810743 ,
#         0.52493227],
#        [0.510451  , 0.5049818 , 0.52731055, ..., 0.49929017, 0.41922548,
#         0.5117725 ],
#        [0.55310667, 0.55000854, 0.49361286, ..., 0.61038864, 0.56476027,
#         0.5584213 ],
#        ...,
#        [0.53198993, 0.4686342 , 0.4757852 , ..., 0.4829717 , 0.49911857,
#         0.49006635],
#        [0.44709045, 0.44709045, 0.51587933, ..., 0.466191  , 0.46058592,
#         0.42228428],
#        [0.4182393 , 0.43140814, 0.5063771 , ..., 0.50422466, 0.530922  ,
#         0.44670886]], dtype=float32)

# %%
print(query_id.shape)
scores.shape
# Out:
# (10417,)
# (10417, 10)

# %%
answer = np.column_stack((query_id,scores))

# %%
answer = pd.DataFrame(answer)
