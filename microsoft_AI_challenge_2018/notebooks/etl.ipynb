# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os 

np.random.seed = 0

# pd.set_option('display.height', 1000)
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# pd.set_option('max_colwidth', 1000)
# pd.set_option('display.expand_frame_repr', False)

# %%
in_f = '../data/data.tsv'
out_f = '../data/data_p.tsv'
chunksize = 1000
df = pd.read_csv(in_f, sep='\t', header=None, index_col=False)
# df = pd.read_csv(in_f, sep='\t', header=None, index_col=False, nrows=chunksize)
# df.to_csv('../data/data_small.tsv', sep='\t', index=False, header=False)
df
# Out:
#           0                                               1  \
# 0       131                        . what is a corporation?
# 1       131                        . what is a corporation?
# 2       131                        . what is a corporation?
# 3       131                        . what is a corporation?
# 4       131                        . what is a corporation?
# 5       131                        . what is a corporation?
# 6       131                        . what is a corporation?
# 7       131                        . what is a corporation?
# 8       131                        . what is a corporation?
# 9       131                        . what is a corporation?
# 10   226969                       symptoms of a dying mouse
# 11   226969                       symptoms of a dying mouse
# 12   226969                       symptoms of a dying mouse
# 13   226969                       symptoms of a dying mouse
# 14   226969                       symptoms of a dying mouse
# 15   226969                       symptoms of a dying mouse
# 16   226969                       symptoms of a dying mouse
# 17   226969                       symptoms of a dying mouse
# 18   226969                       symptoms of a dying mouse
# 19   226969                       symptoms of a dying mouse
# 20    18122     average number of lightning strikes per day
# 21    18122     average number of lightning strikes per day
# 22    18122     average number of lightning strikes per day
# 23    18122     average number of lightning strikes per day
# 24    18122     average number of lightning strikes per day
# 25    18122     average number of lightning strikes per day
# 26    18122     average number of lightning strikes per day
# 27    18122     average number of lightning strikes per day
# 28    18122     average number of lightning strikes per day
# 29    18122     average number of lightning strikes per day
# ..      ...                                             ...
# 970  163855  how to get rid of mosquitoes in yard naturally
# 971  163855  how to get rid of mosquitoes in yard naturally
# 972  163855  how to get rid of mosquitoes in yard naturally
# 973  163855  how to get rid of mosquitoes in yard naturally
# 974  163855  how to get rid of mosquitoes in yard naturally
# 975  163855  how to get rid of mosquitoes in yard naturally
# 976  163855  how to get rid of mosquitoes in yard naturally
# 977  163855  how to get rid of mosquitoes in yard naturally
# 978  163855  how to get rid of mosquitoes in yard naturally
# 979  163855  how to get rid of mosquitoes in yard naturally
# 980   96535   how batting average is calculated in baseball
# 981   96535   how batting average is calculated in baseball
# 982   96535   how batting average is calculated in baseball
# 983   96535   how batting average is calculated in baseball
# 984   96535   how batting average is calculated in baseball
# 985   96535   how batting average is calculated in baseball
# 986   96535   how batting average is calculated in baseball
# 987   96535   how batting average is calculated in baseball
# 988   96535   how batting average is calculated in baseball
# 989   96535   how batting average is calculated in baseball
# 990  149546                     how much is a video editor?
# 991  149546                     how much is a video editor?
# 992  149546                     how much is a video editor?
# 993  149546                     how much is a video editor?
# 994  149546                     how much is a video editor?
# 995  149546                     how much is a video editor?
# 996  149546                     how much is a video editor?
# 997  149546                     how much is a video editor?
# 998  149546                     how much is a video editor?
# 999  149546                     how much is a video editor?
#
#                                                      2  3  4
# 0    A company is incorporated in a specific nation...  0  0
# 1    Today, there is a growing community of more th...  0  1
# 2    Corporation definition, an association of indi...  0  2
# 3    Examples of corporation in a Sentence. 1  He w...  0  3
# 4    1: a government-owned corporation (as a utilit...  0  4
# 5    McDonald's Corporation is one of the most reco...  1  5
# 6    Corporations are owned by their stockholders (...  0  6
# 7    An Association is an organized group of people...  0  7
# 8    B Corp certification shines a light on the com...  0  8
# 9    LLCs offer greater flexibility when it comes t...  0  9
# 10   This can be fatal quite quickly to mice. 1  It...  0  0
# 11   The symptoms of mites include: 1  excessive sc...  0  1
# 12   Symptoms of Dog and Cat Poisoning. The symptom...  0  2
# 13   The symptoms of mites include: excessive scrat...  0  3
# 14   Seizures and neurologic symptoms are caused by...  0  4
# 15   The symptoms are similar but the mouse will be...  1  5
# 16   The symptoms are similar but the mouse will be...  0  6
# 17   Depending on the poison ingested, a poisoned d...  0  7
# 18   Some plants also cause neurologic symptoms, in...  0  8
# 19   She described symptoms caused by permethrin: d...  0  9
# 20   Lightning is a major cause of storm related de...  0  0
# 21   Quick Answer. Lightning strikes reach the grou...  0  1
# 22   An average lightning strike discharges about 3...  0  2
# 23   Lightning fatalities in the U.S.: A map of tot...  0  3
# 24   Lightning is a sudden high-voltage discharge o...  0  4
# 25   Although many lightning flashes are simply clo...  1  5
# 26   According to the NWS Storm Data, over the last...  0  6
# 27   Approximately 300,000 lightning strikes hit th...  0  7
# 28   Florida is also the state with the highest num...  0  8
# 29   There is estimated to be around 2,000 lightnin...  0  9
# ..                                                 ... .. ..
# 970  The mosquitoes will fly into the beer and die ...  0  0
# 971  Consider making your own homemade garlic spray...  0  1
# 972  Keeping Mosquitoes Away from Your Skin. 1  1. ...  0  2
# 973  Repelling Them From Your Yard. 1  1. Use citro...  1  3
# 974  Mosquitoes can hatch and begin looking for pre...  0  4
# 975  This is one of the most effective ways to mini...  0  5
# 976  Repelling Them From Your Yard. 1  1. Use citro...  0  6
# 977  Contents. 1  Mosquito Facts. 2  Signs of Mosqu...  0  7
# 978  Encourage better drainage in your yard if you ...  0  8
# 979  The Mosquito Plant. The Lemon-scented Geranium...  0  9
# 980  Can someone explain to me how batting averages...  0  0
# 981  Calculating Batting Average. Batting Averages ...  0  1
# 982  In baseball, the batting average (BA) is defin...  1  2
# 983  Batting average is a measure of a players batt...  0  3
# 984  Fortunately for rabid baseball fans everywhere...  0  4
# 985  Baseball Batting Average Calculator. In baseba...  0  5
# 986  To calculate batting average simply enter the ...  0  6
# 987  Batting Average is a baseball statistic used p...  0  7
# 988  1 Batting average = the number of hits / the n...  0  8
# 989  To calculate batting average simply enter the ...  0  9
# 990  VideoPad Video Editor Frequently Asked Questio...  0  0
# 991  Average Film and Video Editor Hourly Wage in t...  1  1
# 992  But first things first, let us discuss the typ...  0  2
# 993  Based on the rates I'm going to guess nicebird...  0  3
# 994  Not at all. I had a couple years on an Avid in...  0  4
# 995  500-800 a day freelance, mostly reality, in LA...  0  5
# 996  This means that your video editing rates are a...  0  6
# 997  In a recent survey conducted by Indeed.com, th...  0  7
# 998  Pre-download and sales related questions. If y...  0  8
# 999  Average Film and Video Editor Yearly Salary in...  0  9
#
# [1000 rows x 5 columns]

# %%
len(df)
# Out:
# 5241880

# %%
split=0.9
rows = len(df)

rows_train = int(np.floor(rows*split))
print(rows_train)

df.iloc[:rows_train,].to_csv('../data/traindata.tsv', sep='\t', index=False)
df.iloc[rows_train:,].to_csv('../data/validationdata.tsv', sep='\t', index=False)
# Out:
# 4717692

# %%
pd.read_csv('../data/validationdata.tsv', sep='\t', nrows=5)
# Out:
#         0                    1  \
# 0  573761  what is thighplasty
# 1  573761  what is thighplasty
# 2  573761  what is thighplasty
# 3  573761  what is thighplasty
# 4  573761  what is thighplasty
#
#                                                    2  3  4
# 0  Thigh Lift (Thighplasty). A thighplasty, commo...  0  0
# 1  Buttock/Thigh Lift (Thighplasty). A thighplast...  0  3
# 2  A thighplasty, also called thigh lift, is inte...  0  4
# 3  While the inner thigh lift is by far the most ...  0  8
# 4  Fortunately, plastic surgery offers a potentia...  0  7

# %%
in_f = '../data/traindata.tsv'
out_f = '../data/traindata_p.tsv'
chunksize = 10000

def preprocess(in_f, out_f, chunksize):
    if os.path.exists(out_f):
        os.remove(out_f)
    reader = pd.read_csv(in_f, sep='\t', chunksize=chunksize, index_col=False, header=None)
    print('chunking')
    for chunk in tqdm(reader):
#         chunk.columns = ['query_id', 'query', 'passage_text', 'label', 'passage_id']
#         result1 = chunk[chunk.label==1]
        result1 = chunk[chunk.iloc[:,3]==1]
        result0 = chunk[chunk.iloc[:,3]==0].sample(frac =1/9) 
        result = pd.concat([result1, result0], axis=0).sample(frac=1) 
        result.to_csv(out_f, sep='\t',  mode='a', index=False, header=False)
                        
preprocess(in_f, out_f, chunksize)
# Out:
# chunking
# 472it [00:52,  8.92it/s]

# %%
in_f = '../data/validationdata.tsv'
out_f = '../data/validationdata_p.tsv'
chunksize = 10000
                        
preprocess(in_f, out_f, chunksize)
# Out:
# chunking
# 53it [00:05,  9.43it/s]

# %%
# rows = len(train)/2
# split=0.9
# rows_train = int(np.floor(rows*split))
# df = pd.read_csv(out_f, nrows=rows, sep='\t',index_col=False)
# df.iloc[:rows_train,].to_csv('../data/traindata_p.tsv', sep='\t', index=False)
# df.iloc[rows_train:,].to_csv('../data/validationdata_p.tsv', sep='\t', index=False)
