# %%
from collections import Counter
import pickle

import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
data = pd.read_csv('../data/pre-answer.tsv', sep='\t', names=['query_id', 'query_text', 'passage_text', 'passage_id', 'cs'])
data.head()
# Out:
#    query_id                                 query_text  \
# 0   1135787  distance between erie in buffalo new york
# 1   1135787  distance between erie in buffalo new york
# 2   1135787  distance between erie in buffalo new york
# 3   1135787  distance between erie in buffalo new york
# 4   1135787  distance between erie in buffalo new york
#
#                                         passage_text  passage_id        cs
# 0  Erie Canal Distance Tables The Erie Canal is t...           0  0.000000
# 1  What is the distance between Erie AND Buffalo?...           1 -0.205710
# 2  The distance between Erie and Buffalo in a str...           2 -0.205710
# 3  Erie Canal Distances. Erie Canal Distance Tabl...           3 -0.205710
# 4  Erie's Metropolitan Area consists of approxima...           4 -0.205711

# %%
uniq, index = np.unique(data['query_id'], return_index=True)
query_id = uniq[index.argsort()]
query_id[:5]
# Out:
# array([1135787,  281922,  120233,  319757,  193633], dtype=int64)

# %%
scores = data['cs'].values.reshape(-1,10)
print(scores.shape)
scores
# Out:
# (10417, 10)
# array([[ 0.        , -0.20571008, -0.20570987, ..., -0.20571014,
#         -0.20571008, -0.20570993],
#        [-0.20571001, -0.20570999, -0.20570999, ..., -0.2057102 ,
#         -0.20570996, -0.20570999],
#        [-0.20570984, -0.20570979, -0.20570976, ..., -0.20570992,
#         -0.20570964, -0.20570993],
#        ...,
#        [-0.20570938, -0.20570943, -0.20570922, ..., -0.20570926,
#         -0.20570952, -0.20570922],
#        [-0.20570958, -0.20570943, -0.20570967, ..., -0.20570934,
#         -0.20570946, -0.20570932],
#        [-0.20570956, -0.2057102 , -0.20570976, ..., -0.20571013,
#         -0.2057097 , -0.2057097 ]])

# %%
print(query_id.shape)
scores.shape
# Out:
# (10417,)
# (10417, 10)

# %%
answer = np.column_stack((query_id,scores))

# %%
answer = pd.DataFrame(answer)
answer.iloc[:,0] = answer.iloc[:,0].astype('int')
answer.to_csv('../data/answer.tsv', sep='\t', header=None, index=False)
answer.head(n=50)
# Out:
#          0         1         2         3         4         5         6   \
# 0   1135787  0.000000 -0.205710 -0.205710 -0.205710 -0.205711 -0.205710
# 1    281922 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 2    120233 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 3    319757 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 4    193633 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 5     50229 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 6    130810 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 7    138208 -0.205710 -0.205710 -0.205710 -0.205709 -0.205710 -0.205710
# 8    334554 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 9    204203 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 10    17356 -0.205710 -0.205711 -0.205710 -0.205710 -0.205710 -0.205710
# 11   253939 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 12  1135786 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 13   231134 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205711
# 14   341964 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 15   303614 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 16   292073 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 17   105519 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 18   176276 -0.205710 -0.205710 -0.205711 -0.205710 -0.205710 -0.205710
# 19  1125010 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 20   275413 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 21   146062 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 22   322031 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 23  1125005 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 24   234528 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205711
# 25   169964 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 26    18308 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205709
# 27   358178 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 28   105198 -0.205710 -0.205710 -0.205710 -0.205711 -0.205710 -0.205710
# 29   161755 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 30   283106 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 31   253834 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 32   301162 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 33  1124997 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 34   305205 -0.205710 -0.205710 -0.205711 -0.205710 -0.205710 -0.205710
# 35    43323 -0.205711 -0.205711 -0.205710 -0.205710 -0.205710 -0.205710
# 36  1124995 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 37   119821 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
# 38    28484 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710 -0.205710
#